# %% [markdown]
# # RQ4 completed-artifact reader / Lector de artefactos terminados RQ4
# This notebook never runs GroundingDINO, fits models, calibrates, or changes scientific results. / Este notebook nunca ejecuta GroundingDINO, ajusta modelos, calibra ni cambia resultados científicos.

# %%
from pathlib import Path
import json
import pandas as pd
root = Path('../outputs')
metrics = json.loads((root / 'metrics.json').read_text(encoding='utf-8'))
main = pd.read_csv(root / 'Table_RQ4_main.csv')
primary = pd.read_csv(root / 'Table_RQ4_primary_inference.csv')
main, primary, metrics['evidence_status']
