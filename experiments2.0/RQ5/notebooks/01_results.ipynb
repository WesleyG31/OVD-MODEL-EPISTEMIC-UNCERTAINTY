# %% [markdown]
# # RQ5 completed-artifact reader
# This notebook never trains models or runs GroundingDINO. Mini outputs are diagnostic only.

# %%
from pathlib import Path
import json
import pandas as pd
root = Path('../outputs')
metrics = json.loads((root / 'metrics.json').read_text(encoding='utf-8'))
main = pd.read_csv(root / 'Table_RQ5_main.csv')
main
